# %%
import json
from urllib.parse import parse_qs

# %%
with open("./runs/default/dag_snapshot.json") as f:
    snapshot = json.load(f)

# %%
snapshot
# Out:
# {'est=model_A&syst=nominal&ensem=0&fold=0': '/work/kschmidt/NEEDLE/needle-sbi/runs/default/est__model_A/syst__nominal/ensem__0/fold__0/model.ckpt'}

# %%
parse_qs('est=model_A&syst=nominal&ensem=0&fold=0')
# Out:
# {'est': ['model_A'], 'syst': ['nominal'], 'ensem': ['0'], 'fold': ['0']}
