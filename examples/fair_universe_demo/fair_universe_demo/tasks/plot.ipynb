# %%
import gallery

# %%
gallery.generate(
   config=gallery.GalleryConfig(
        web_folder="/web/kschmidt/public_html",
        sources=[gallery.GallerySource(
            name="fixed_normalization",
            path="/work/kschmidt/NEEDLE/orchestrator/runs/fair_universe_demo_fixed_normalization/plots",
        )]
    ),
    verbose=True,
)
# Out:
# Updated assets from /work/kschmidt/NEEDLE/orchestrator/.venv/lib64/python3.12/site-packages/gallery/assets to /web/kschmidt/public_html/assets
# ...
# ✓ Gallery generated successfully at /web/kschmidt/public_html/gallery
# True
