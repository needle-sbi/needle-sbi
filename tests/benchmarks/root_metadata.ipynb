# %%
import uproot
import dask_awkward as dak
import pickle
import os

DELPHES_DATA_ROOT = os.getenv("DELPHES_DATA_ROOT")

# %%
def filter_name_func(name: str) -> bool:
    return not any(d in name for d in ["fBits"])

# %%
metadata = []

for i, array in enumerate(uproot.iterate(
    files=DELPHES_DATA_ROOT,
    filter_name=filter_name_func,
)):
