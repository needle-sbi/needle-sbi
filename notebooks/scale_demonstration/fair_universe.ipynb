# %%
import pandas as pd
import os

# %%
df = pd.read_parquet(os.getenv("FAIR_UNIVERSE_DATA"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157016124 entries, 0 to 157016123
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   PRI_lep_pt              float32
#  1   PRI_lep_eta             float32
#  2   PRI_lep_phi             float32
#  3   PRI_had_pt              float32
#  4   PRI_had_eta             float32
#  5   PRI_had_phi             float32
#  6   PRI_jet_leading_pt      float32
#  7   PRI_jet_leading_eta     float32
#  8   PRI_jet_leading_phi     float32
#  9   PRI_jet_subleading_pt   float32
#  10  PRI_jet_subleading_eta  float32
#  11  PRI_jet_subleading_phi  float32
#  12  PRI_n_jets              float32
#  13  PRI_jet_all_pt          float32
#  14  PRI_met                 float32
#  15  PRI_met_phi             float32
# dtypes: float32(16)
# memory usage: 9.4 GB
